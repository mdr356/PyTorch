# %%
Adding Relu activation adds non-linearity to the problem. that is why accuracy is higher than privous version. Since previous version is only a linear function.

# %%
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import torch
import numpy as np
import torch.nn as nn

# %%
# get data from sklearn datasets 
X, y = make_circles(n_samples=1000, shuffle=True, noise=0.02, random_state=42)
X[:5],y[:5]
# graph data
plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.RdYlBu)

# %%
# turn data to tensor and float32 datatype
X = torch.from_numpy(X).type(torch.float)
y = torch.from_numpy(y).type(torch.float)

# create train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)
len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (750, 750, 250, 250)

# %%
X_train[:5], y_train[:5]
# Out:
# (tensor([[ 0.3214, -0.7403],
#          [-0.3083,  0.9467],
#          [-0.4946, -0.6449],
#          [-0.8783,  0.4797],
#          [ 0.7482, -0.6957]]),
#  tensor([1., 0., 1., 0., 0.]))

# %%
class BinaryClassificationV2(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_one = nn.Linear(in_features=2,
                                   out_features=10)
        self.layer_two = nn.Linear(in_features=10,
                                   out_features=10)
        self.layer_three = nn.Linear(in_features=10,
                                     out_features=1)
        self.relu = nn.ReLU() # <- add in ReLU activation function


    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.layer_three(self.relu(self.layer_two(self.layer_one(x))))

# %%
def accuracy(y_true, y_values):
    correct = torch.eq(y_true, y_values).sum().item()
    acc = (correct / len(y_values))*100
    return acc

# %%
# Create model
model_v1 = BinaryClassificationV2()

# loss function
loss_fn = nn.BCEWithLogitsLoss()
# optimizer
optimizer = torch.optim.SGD(model_v1.parameters(), lr=0.01)

# %%
# training
torch.manual_seed(42)
epochs = 10000
epoch_count = []
for epoch in range(epochs):
    model_v1.train()

    logits = model_v1(X_train).squeeze() # the output of sigmoif from BCE with logits is logits and it has one dimenstion. the Squeeze remove the dimension
    loss = loss_fn(logits, y_train) #3 calculate the loss 
    y_preds = torch.round(torch.sigmoid(logits)) # make prediction 

    acc = accuracy(y_preds, y_train) # calculate accuracy which is correct valuees of overall values times 100
    optimizer.zero_grad() # make backpropagation not take into account preivous gradients 

    loss.backward() # perform backpropagation
    optimizer.step() # update weights and bias base on backpropagation gradient descent.

    #test
    model_v1.eval()
    with torch.inference_mode():
        test_logits = model_v1(X_test).squeeze()
        test_loss = loss_fn(test_logits, y_test)

        test_y_preds = torch.round(torch.sigmoid(test_logits))
        test_acc = accuracy(test_y_preds, y_test)

        if epoch % 1000 == 0:
            print(f"Epoch: {epoch}, Train Acc : {acc}%, Train Loss: {loss}, Test Acc: {test_acc}%, Test Loss: {test_loss}")
# Out:
# Epoch: 0, Train Acc : 100.0%, Train Loss: 0.015968136489391327, Test Acc: 99.6%, Test Loss: 0.01779642142355442
# Epoch: 1000, Train Acc : 100.0%, Train Loss: 0.014686514623463154, Test Acc: 99.6%, Test Loss: 0.01659495197236538
# Epoch: 2000, Train Acc : 100.0%, Train Loss: 0.013581880368292332, Test Acc: 99.6%, Test Loss: 0.015504070557653904
# Epoch: 3000, Train Acc : 100.0%, Train Loss: 0.012623514980077744, Test Acc: 100.0%, Test Loss: 0.014591630548238754
# Epoch: 4000, Train Acc : 100.0%, Train Loss: 0.01178447250276804, Test Acc: 100.0%, Test Loss: 0.013800837099552155
# Epoch: 5000, Train Acc : 100.0%, Train Loss: 0.011044370010495186, Test Acc: 100.0%, Test Loss: 0.013105371035635471
# Epoch: 6000, Train Acc : 100.0%, Train Loss: 0.01038709282875061, Test Acc: 100.0%, Test Loss: 0.01248852163553238
# Epoch: 7000, Train Acc : 100.0%, Train Loss: 0.009799757972359657, Test Acc: 100.0%, Test Loss: 0.011938080191612244
# Epoch: 8000, Train Acc : 100.0%, Train Loss: 0.009272031486034393, Test Acc: 100.0%, Test Loss: 0.011443358846008778
# Epoch: 9000, Train Acc : 100.0%, Train Loss: 0.008795392699539661, Test Acc: 100.0%, Test Loss: 0.01099690143018961
